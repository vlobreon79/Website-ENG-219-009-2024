# %% [markdown]
# <a href="https://colab.research.google.com/github/vlobreon79/Website-ENG-219-009-2024/blob/main/Website_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile index.html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Victoria Chebet Rotich</title>
# </head>
# <body>
#
#     <h1>Victoria Chebet Rotich</h1>
#     <p><strong>Registration Number:</strong> ENG-219-009/2024</p>
#
#     <h2>About Me</h2>
#     <p>
#         My name is Victoria Chebet Rotich. I am a student studying Python.
#         I am interested in learning programming and improving my skills in technology.
#     </p>
#
#     <h2>Hobbies</h2>
#     <ul>
#         <li>Reading</li>
#         <li>Listening to music</li>
#         <li>Watching movies</li>
#         <li>Coding</li>
#     </ul>
#
#     <h2>Skills</h2>
#     <ul>
#         <li>Basic Python Programming</li>
#         <li>HTML</li>
#         <li>Problem Solving</li>
#         <li>Teamwork</li>
#     </ul>
#
#     <hr>
#
#     <p>&copy; 2026 Victoria Chebet Rotich</p>
#
# </body>
# </html>
# Out:
# Writing index.html

# %%
from IPython.display import HTML

# Read the content of the HTML file
with open('index.html', 'r') as f:
    html_content = f.read()

# Display the HTML content
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Victoria Chebet Rotich</title>
# </head>
# <body>
#
#     <h1>Victoria Chebet Rotich</h1>
#     <p><strong>Registration Number:</strong> ENG-219-009/2024</p>
#
#     <h2>About Me</h2>
#     <p>
#         My name is Victoria Chebet Rotich. I am a student studying Python.
#         I am interested in learning programming and improving my skills in technology.
#     </p>
#
#     <h2>Hobbies</h2>
#     <ul>
#         <li>Reading</li>
#         <li>Listening to music</li>
#         <li>Watching movies</li>
#         <li>Coding</li>
#     </ul>
#
#     <h2>Skills</h2>
#     <ul>
#         <li>Basic Python Programming</li>
#         <li>HTML</li>
#         <li>Problem Solving</li>
#         <li>Teamwork</li>
#     </ul>
#
#     <hr>
#
#     <p>&copy; 2026 Victoria Chebet Rotich</p>
#
# </body>
# </html>
